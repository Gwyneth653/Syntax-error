# %% [markdown]
# # Predicting House Prices
#
# Nowadays, housing prices are extremely on the rise due to the increase in demand. It is really hard to get your hands on a house and even if you do, it has become normal to pay much more than the original sales price of the house.
#
# When thinking about the sales price of a house, most people think this is a combination of the size of the lot, the amount of bedrooms and the location. However, many more unfamiliar features determine the sales price of a house. Given a dataset with 79 features, both a mixture of categorical and numerical features, we are going to estimate the value of houses in Ames Iowa. Since there are only 1460 training examples the challenge to train a model that generalizes well to new examples arises. Creating a model which predicts housing prices will help to solve real world problems because housing prices can in this way be computed in a more rational way.

# %% [markdown]
# ## Import the necessary modules and libraries

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from sklearn import preprocessing
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Import data

# %%
train_data = pd.read_csv('train.csv')

# %% [markdown]
# ## Inspect data

# %% [markdown]
# ### Data information

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
#  17  OverallQual    1460 non-null   int64
#  18  OverallCond    1460 non-null   int64
#  19  YearBuilt      1460 non-null   int64
#  20  YearRemodAdd   1460 non-null   int64
#  21  RoofStyle      1460 non-null   object
#  22  RoofMatl       1460 non-null   object
#  23  Exterior1st    1460 non-null   object
#  24  Exterior2nd    1460 non-null   object
#  25  MasVnrType     1452 non-null   object
#  26  MasVnrArea     1452 non-null   float64
#  27  ExterQual      1460 non-null   object
#  28  ExterCond      1460 non-null   object
#  29  Foundation     1460 non-null   object
#  30  BsmtQual       1423 non-null   object
#  31  BsmtCond       1423 non-null   object
#  32  BsmtExposure   1422 non-null   object
#  33  BsmtFinType1   1423 non-null   object
#  34  BsmtFinSF1     1460 non-null   int64
#  35  BsmtFinType2   1422 non-null   object
#  36  BsmtFinSF2     1460 non-null   int64
#  37  BsmtUnfSF      1460 non-null   int64
#  38  TotalBsmtSF    1460 non-null   int64
#  39  Heating        1460 non-null   object
#  40  HeatingQC      1460 non-null   object
#  41  CentralAir     1460 non-null   object
#  42  Electrical     1459 non-null   object
#  43  1stFlrSF       1460 non-null   int64
#  44  2ndFlrSF       1460 non-null   int64
#  45  LowQualFinSF   1460 non-null   int64
#  46  GrLivArea      1460 non-null   int64
#  47  BsmtFullBath   1460 non-null   int64
#  48  BsmtHalfBath   1460 non-null   int64
#  49  FullBath       1460 non-null   int64
#  50  HalfBath       1460 non-null   int64
#  51  BedroomAbvGr   1460 non-null   int64
#  52  KitchenAbvGr   1460 non-null   int64
#  53  KitchenQual    1460 non-null   object
#  54  TotRmsAbvGrd   1460 non-null   int64
#  55  Functional     1460 non-null   object
#  56  Fireplaces     1460 non-null   int64
#  57  FireplaceQu    770 non-null    object
#  58  GarageType     1379 non-null   object
#  59  GarageYrBlt    1379 non-null   float64
#  60  GarageFinish   1379 non-null   object
#  61  GarageCars     1460 non-null   int64
#  62  GarageArea     1460 non-null   int64
#  63  GarageQual     1379 non-null   object
#  64  GarageCond     1379 non-null   object
#  65  PavedDrive     1460 non-null   object
#  66  WoodDeckSF     1460 non-null   int64
#  67  OpenPorchSF    1460 non-null   int64
#  68  EnclosedPorch  1460 non-null   int64
#  69  3SsnPorch      1460 non-null   int64
#  70  ScreenPorch    1460 non-null   int64
#  71  PoolArea       1460 non-null   int64
#  72  PoolQC         7 non-null      object
#  73  Fence          281 non-null    object
#  74  MiscFeature    54 non-null     object
#  75  MiscVal        1460 non-null   int64
#  76  MoSold         1460 non-null   int64
#  77  YrSold         1460 non-null   int64
#  78  SaleType       1460 non-null   object
#  79  SaleCondition  1460 non-null   object
#  80  SalePrice      1460 non-null   int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %% [markdown]
# ### Missing values

# %%
def show_missing_info(df):
    
    '''This function detects missing values in a dataframe and returns a dataframe of features with missing
    values and the number of rows with and percentage of missing values within that feature in descending order.'''
    
    missing_info = df.isna().sum().reset_index(drop=False)
    missing_info.columns = ["column","rows"]
    missing_info["percentage missing"] = (missing_info["rows"]/train_data.shape[0])*100
    missing_info = missing_info[missing_info["rows"]>0].sort_values(by="percentage missing",ascending=False)
    return missing_info

# Show information about features with missing values in the train data
missing_df = show_missing_info(train_data)
print(f'Features with missing values:\n', missing_df)

# Make a list of the top 5 features with the most missing values in the train data
all_missing = list(missing_df['column'])
top5_mv = list(missing_df['column'].head(5))
print(f'\n Features that will be dropped from the dataset:\n', top5_mv)
# Out:
# Features with missing values:
#            column  rows  percentage missing
# 72        PoolQC  1453           99.520548
# 74   MiscFeature  1406           96.301370
# 6          Alley  1369           93.767123
# 73         Fence  1179           80.753425
# 57   FireplaceQu   690           47.260274
# 3    LotFrontage   259           17.739726
# 58    GarageType    81            5.547945
# 59   GarageYrBlt    81            5.547945
# 60  GarageFinish    81            5.547945
# 63    GarageQual    81            5.547945
# 64    GarageCond    81            5.547945
# 32  BsmtExposure    38            2.602740
# 35  BsmtFinType2    38            2.602740
# 33  BsmtFinType1    37            2.534247
# 31      BsmtCond    37            2.534247
# 30      BsmtQual    37            2.534247
# 26    MasVnrArea     8            0.547945
# 25    MasVnrType     8            0.547945
# 42    Electrical     1            0.068493
#
#  Features that will be dropped from the dataset:
#  ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'FireplaceQu']

# %% [markdown]
# ### Visualize sale prices

# %%
# Select the SalePrice (y) from the training data
X_train = train_data.loc[:, train_data.columns != 'SalePrice']
y_train = train_data['SalePrice']

# Create a histogram with seaborn of the SalePrice (y) from train data
sns.distplot(y_train)
# Out:
# /Users/veerleblom/opt/anaconda3/envs/progLab/lib/python3.7/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='SalePrice', ylabel='Density'>

# %% [markdown]
# As you can see in the plot, most of the houses are sold for a price between 100000 and 200000 dollars. However, there are outliers on the precier side.

# %% [markdown]
# ## Prepare data
#
# We will make some adjustments in the data set in order to make the data useful as input to the model.
#
# 1. Clean data
#     - Drop features that are in the top 5 features that include the most missing values
#     - Replace other missing numerical data with the mean value of that feature
#     - Replace other missing categorical data with the most common category of that feature)
# 2. One-hot encode categorical data
# 3. Select features in data set with a high correlation with the SalePrice
# 3. Ramdomly devide data set into 70% train data and 30% validation data

# %%
def one_hot_encoding(df):
    
    '''One hot encode categorical data from a dataframe.'''
        
    # Select all categorical features and numberical features
    cat_data = df.select_dtypes(include=[object])
    num_data = df.select_dtypes(exclude=[object])
    
    # Create a LabelEncoder object and apply it to each categorical feature in the data
    le = preprocessing.LabelEncoder()
    cat_data_2 = cat_data.apply(le.fit_transform)
    
    # Create an OneHotEncoder object and fit it to all categorical data
    enc = preprocessing.OneHotEncoder()
    enc.fit(cat_data_2)
    onehotlabels = enc.transform(cat_data_2).toarray()
    
    # Get all possible categories from the data
    all_categories = enc.get_feature_names(cat_data_2.columns)

    # Create new dataframe with all possible categories as columns
    cat_data = pd.DataFrame(onehotlabels, columns = all_categories)
    
    # Merge the numerical data with the one hot encoded categorical data again
    result = pd.concat([cat_data, num_data], axis=1).reindex(cat_data.index)
        
    return result

# %%
def cleaning(df):
    
    '''This function corrects any missing values in a pandas dataframe and
    returns the cleaned dataframe.'''
    
    # Loop through all the features/columns in the training data
    for column in df:
                
        # if column is in top 5 of columns with most missing data, drop column
        if column in top5_mv:
            df = df.drop(columns=[column])
        
        # check whether the data in each column is numerical
        elif is_numeric_dtype(df[column]):

            # if the data is numerical compute the mean of the whole column values
            column_mean = df[column].mean()

            # replace the missing values in this column with the mean of the column
            df[column] = df[column].fillna(column_mean)

        # replace categorical missing values with the most common categorical value
        else:
            df[column] = df[column].fillna(df[column].value_counts().index[0])
    
    return df

# Clean and one hot encode data in dataframe
train_data_cleaned = cleaning(train_data)
train_data_oh = one_hot_encoding(train_data_cleaned)
# Out:
# /Users/veerleblom/opt/anaconda3/envs/progLab/lib/python3.7/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# ## Split SalePrice (y) from train data (X)

# %%
X_train = train_data_oh.loc[:, train_data_oh.columns != 'SalePrice']
y_train = train_data_oh['SalePrice']

# %% [markdown]
# ## Select features from the train data with a high correlation with the SalePrice

# %%
# Compute correlation coefficients
train_data_oh.corr(method="pearson")
# Out:
#             MSZoning_0  MSZoning_1  MSZoning_2  MSZoning_3  MSZoning_4  \
# MSZoning_0    1.000000   -0.017926   -0.008742   -0.160278   -0.034792
# MSZoning_1   -0.017926    1.000000   -0.022722   -0.416608   -0.090435
# MSZoning_2   -0.008742   -0.022722    1.000000   -0.203158   -0.044101
# MSZoning_3   -0.160278   -0.416608   -0.203158    1.000000   -0.808585
# MSZoning_4   -0.034792   -0.090435   -0.044101   -0.808585    1.000000
# ...                ...         ...         ...         ...         ...
# PoolArea     -0.005705   -0.014828   -0.007231    0.035591   -0.028779
# MiscVal       0.002999   -0.018928   -0.009230    0.016581   -0.006047
# MoSold        0.042344   -0.003594    0.045883   -0.003429   -0.017192
# YrSold        0.030290    0.004943   -0.025035    0.012716   -0.017131
# SalePrice    -0.111257    0.089950   -0.065429    0.245063   -0.288065
#
#             Street_0  Street_1  LotShape_0  LotShape_1  LotShape_2  ...  \
# MSZoning_0  0.254287 -0.254287   -0.040840   -0.014116   -0.006897  ...
# MSZoning_1 -0.013866  0.013866   -0.081464    0.023612   -0.017926  ...
# MSZoning_2 -0.006762  0.006762   -0.046176    0.021930   -0.008742  ...
# MSZoning_3 -0.045348  0.045348    0.261574    0.027175    0.022698  ...
# MSZoning_4  0.003127 -0.003127   -0.229711   -0.047949   -0.011491  ...
# ...              ...       ...         ...         ...         ...  ...
# PoolArea   -0.004413  0.004413    0.017269   -0.011676    0.093544  ...
# MiscVal     0.022733 -0.022733    0.043950   -0.006713   -0.007282  ...
# MoSold     -0.003690  0.003690    0.032942    0.002763   -0.003746  ...
# YrSold      0.025043 -0.025043   -0.035973    0.004853   -0.026006  ...
# SalePrice  -0.041036  0.041036    0.223284    0.126096    0.036720  ...
#
#             WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# MSZoning_0   -0.055969     0.022243       0.082295  -0.009661    -0.007689
# MSZoning_1   -0.063687     0.185169      -0.077563  -0.025113    -0.046530
# MSZoning_2   -0.022364    -0.029259       0.063286  -0.012246    -0.028443
# MSZoning_3    0.167734    -0.044253      -0.159896   0.051525     0.061666
# MSZoning_4   -0.135901    -0.053039       0.190614  -0.038708    -0.033662
# ...                ...          ...            ...        ...          ...
# PoolArea      0.073378     0.060762       0.054203  -0.007992     0.051307
# MiscVal      -0.009551    -0.018584       0.018361   0.000354     0.031946
# MoSold        0.021011     0.071255      -0.028887   0.029474     0.023217
# YrSold        0.022270    -0.057619      -0.009916   0.018645     0.010694
# SalePrice     0.324413     0.315856      -0.128578   0.044584     0.111447
#
#             PoolArea   MiscVal    MoSold    YrSold  SalePrice
# MSZoning_0 -0.005705  0.002999  0.042344  0.030290  -0.111257
# MSZoning_1 -0.014828 -0.018928 -0.003594  0.004943   0.089950
# MSZoning_2 -0.007231 -0.009230  0.045883 -0.025035  -0.065429
# MSZoning_3  0.035591  0.016581 -0.003429  0.012716   0.245063
# MSZoning_4 -0.028779 -0.006047 -0.017192 -0.017131  -0.288065
# ...              ...       ...       ...       ...        ...
# PoolArea    1.000000  0.029669 -0.033737 -0.059689   0.092404
# MiscVal     0.029669  1.000000 -0.006495  0.004906  -0.021190
# MoSold     -0.033737 -0.006495  1.000000 -0.145721   0.046432
# YrSold     -0.059689  0.004906 -0.145721  1.000000  -0.028923
# SalePrice   0.092404 -0.021190  0.046432 -0.028923   1.000000
#
# [272 rows x 272 columns]

# %%
def select_correlated_features(X_train, y_train, no_features):
    
    '''This function selects x features (=no_features) from X_train which are most correlated
    with the SalePrice (y_train) and returns this subset of X_train.'''
    
    # Determine correlations of features with the sale price in descending order
    correlations = X_train.corrwith(y_train).sort_values(ascending=False)
    
    # Create lists of features with the x highest correlations with the SalePrice
    top_cor = list(correlations.head(no_features).index.values)

    # Only remain features in df which are in that list
    X_train_subset = X_train[X_train.columns.intersection(top_cor)]
    
    return X_train_subset

X_train_subset = select_correlated_features(X_train, y_train, 20)

# %% [markdown]
# ## Divide the data into a train and validation set

# %%
X_train, X_test, y_train, y_test = train_test_split(X_train_subset, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# ## Regression tree
#
# ### Determine the optimal value for max_depth

# %%
model = DecisionTreeRegressor()
depths = np.arange(1, 21, 1)
repitions = np.arange(0, 50)
df = pd.DataFrame(columns =['max_depth', 'rmse'])

# Create a regression tree with every possible value for max_depth between 1 and 100
for n in depths:
    
    # With every value for max_depth, repeat modelling 50 times
    for i in repitions:
        
        # Fit regression model
        model.set_params(max_depth=n)
        model.fit(X_train, y_train)

        # Predict
        y_pred = model.predict(X_test)

        # Compute root mean squared error 
        rmse = np.sqrt(mean_squared_error(y_pred, y_test))
        
        # Add row to dataframe
        df = df.append({'max_depth': n, 'rmse': rmse}, ignore_index=True)
    
# Plot the avg, max, and min rmse of the random forests for every number of estimators
data = df.groupby('max_depth')['rmse'].agg(['min', 'max', 'mean']).reset_index()
ax  = data.plot(x='max_depth', y='mean', c='white')
plt.title("Avg-max-min plot of the RMSE of regression trees depending on max_depth")
plt.xlabel('max_depth')
plt.ylabel('RMSE')
plt.fill_between(x='max_depth',y1='min',y2='max', data=data)
# Out:
#     max_depth           min           max          mean
# 0         1.0  65179.178177  65179.178177  65179.178177
# 1         2.0  50731.027707  50731.027707  50731.027707
# 2         3.0  43364.231509  43364.231509  43364.231509
# 3         4.0  39445.594508  43599.352704  40525.571639
# 4         5.0  35442.918751  44331.325557  38179.915220
# 5         6.0  34271.594874  43056.377829  37656.496251
# 6         7.0  33932.206300  42998.404374  37576.934751
# 7         8.0  35416.538622  44564.330527  39029.802884
# 8         9.0  36478.749214  44988.942815  39428.185604
# 9        10.0  36011.427451  45822.448014  40200.241835
# 10       11.0  36611.758942  44849.025959  40051.340354
# 11       12.0  36852.101294  45169.104996  40233.631220
# 12       13.0  36741.539881  45240.954703  40256.845882
# 13       14.0  36935.091799  46545.808744  40237.576514
# 14       15.0  37148.885152  44179.055066  40018.710543
# 15       16.0  36061.604438  46130.408299  40224.322968
# 16       17.0  36319.273920  44759.497296  39970.477627
# 17       18.0  37509.343266  46547.695215  40839.393085
# 18       19.0  37308.499583  46322.851777  40879.931187
# 19       20.0  37249.593216  46532.262819  40637.104906

# %% [markdown]
# ### Optimal regression tree

# %%
# Fit regression model
regr_1 = DecisionTreeRegressor()
regr_1.fit(X_train, y_train)

# Predict
y_pred1 = regr_1.predict(X_test)

# Compute root mean squared error 
rmse = np.sqrt(mean_squared_error(y_pred1, y_test))
print("RMSE:", rmse)

# Visualize the Decision Tree
text_representation = tree.export_text(regr_1)
print(text_representation)
# Out:
# RMSE: 40467.126720297
# |--- feature_7 <= 7.50
# |   |--- feature_7 <= 6.50
# |   |   |--- feature_13 <= 1378.50
# |   |   |   |--- feature_11 <= 969.50
# |   |   |   |   |--- feature_7 <= 4.50
# |   |   |   |   |   |--- feature_19 <= 205.00
# |   |   |   |   |   |   |--- feature_8 <= 1948.00
# |   |   |   |   |   |   |   |--- feature_13 <= 1116.00
# |   |   |   |   |   |   |   |   |--- feature_16 <= 1.00
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 572.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 522.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  522.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  572.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 758.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  758.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_16 >  1.00
# |   |   |   |   |   |   |   |   |   |--- value: [100000.00]
# |   |   |   |   |   |   |   |--- feature_13 >  1116.00
# |   |   |   |   |   |   |   |   |--- feature_8 <= 1925.00
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 743.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [106250.00]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  743.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [96500.00]
# |   |   |   |   |   |   |   |   |--- feature_8 >  1925.00
# |   |   |   |   |   |   |   |   |   |--- value: [76500.00]
# |   |   |   |   |   |   |--- feature_8 >  1948.00
# |   |   |   |   |   |   |   |--- feature_9 <= 1952.50
# |   |   |   |   |   |   |   |   |--- value: [135000.00]
# |   |   |   |   |   |   |   |--- feature_9 >  1952.50
# |   |   |   |   |   |   |   |   |--- feature_11 <= 861.00
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= 1248.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 744.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  744.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [88000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  1248.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [97000.00]
# |   |   |   |   |   |   |   |   |--- feature_11 >  861.00
# |   |   |   |   |   |   |   |   |   |--- value: [115000.00]
# |   |   |   |   |   |--- feature_19 >  205.00
# |   |   |   |   |   |   |--- feature_11 <= 633.50
# |   |   |   |   |   |   |   |--- feature_13 <= 1321.00
# |   |   |   |   |   |   |   |   |--- feature_13 <= 966.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1951.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 <= 1942.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [60000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 >  1942.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [72500.00]
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  1951.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1986.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  1986.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [86000.00]
# |   |   |   |   |   |   |   |   |--- feature_13 >  966.00
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_18 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [91000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_18 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1971.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  1971.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83500.00]
# |   |   |   |   |   |   |   |--- feature_13 >  1321.00
# |   |   |   |   |   |   |   |   |--- feature_12 <= 768.50
# |   |   |   |   |   |   |   |   |   |--- value: [125500.00]
# |   |   |   |   |   |   |   |   |--- feature_12 >  768.50
# |   |   |   |   |   |   |   |   |   |--- value: [112000.00]
# |   |   |   |   |   |   |--- feature_11 >  633.50
# |   |   |   |   |   |   |   |--- feature_9 <= 1998.00
# |   |   |   |   |   |   |   |   |--- feature_15 <= 4.50
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= 709.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [113000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  709.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1955.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  1955.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_15 >  4.50
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 683.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [80000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  683.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1967.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  1967.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_9 >  1998.00
# |   |   |   |   |   |   |   |   |--- feature_11 <= 648.50
# |   |   |   |   |   |   |   |   |   |--- value: [145000.00]
# |   |   |   |   |   |   |   |   |--- feature_11 >  648.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 3.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [120000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  3.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1952.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [125500.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  1952.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [129500.00]
# |   |   |   |   |--- feature_7 >  4.50
# |   |   |   |   |   |--- feature_19 <= 417.00
# |   |   |   |   |   |   |--- feature_8 <= 1935.50
# |   |   |   |   |   |   |   |--- feature_13 <= 1249.00
# |   |   |   |   |   |   |   |   |--- feature_11 <= 804.50
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 857.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 1147.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  1147.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  857.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 912.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [105000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  912.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [104900.00]
# |   |   |   |   |   |   |   |   |--- feature_11 >  804.50
# |   |   |   |   |   |   |   |   |   |--- feature_19 <= 170.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 882.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  882.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_19 >  170.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 956.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  956.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [102000.00]
# |   |   |   |   |   |   |   |--- feature_13 >  1249.00
# |   |   |   |   |   |   |   |   |--- feature_14 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- feature_19 <= 108.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [127000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_19 >  108.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 785.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  785.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_14 >  1.50
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 781.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [103600.00]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  781.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [112000.00]
# |   |   |   |   |   |   |--- feature_8 >  1935.50
# |   |   |   |   |   |   |   |--- feature_12 <= 550.50
# |   |   |   |   |   |   |   |   |--- feature_10 <= 195.00
# |   |   |   |   |   |   |   |   |   |--- feature_17 <= 1980.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [100000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_17 >  1980.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [106000.00]
# |   |   |   |   |   |   |   |   |--- feature_10 >  195.00
# |   |   |   |   |   |   |   |   |   |--- feature_16 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 <= 1972.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 >  1972.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [83000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_16 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [94500.00]
# |   |   |   |   |   |   |   |--- feature_12 >  550.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 1992.00
# |   |   |   |   |   |   |   |   |   |--- feature_19 <= 356.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 <= 298.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 >  298.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |--- feature_19 >  356.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 879.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  879.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_9 >  1992.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1959.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 1055.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  1055.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  1959.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  5.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- feature_19 >  417.00
# |   |   |   |   |   |   |--- feature_8 <= 1956.00
# |   |   |   |   |   |   |   |--- feature_13 <= 771.00
# |   |   |   |   |   |   |   |   |--- value: [73000.00]
# |   |   |   |   |   |   |   |--- feature_13 >  771.00
# |   |   |   |   |   |   |   |   |--- feature_11 <= 870.00
# |   |   |   |   |   |   |   |   |   |--- feature_19 <= 536.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_19 >  536.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 <= 1959.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 >  1959.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_11 >  870.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 <= 1934.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [163500.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 >  1934.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [100000.00]
# |   |   |   |   |   |   |--- feature_8 >  1956.00
# |   |   |   |   |   |   |   |--- feature_7 <= 5.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 1977.00
# |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_14 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 8
# |   |   |   |   |   |   |   |   |   |   |--- feature_14 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [106000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [149900.00]
# |   |   |   |   |   |   |   |   |--- feature_9 >  1977.00
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= 907.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 849.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  849.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  907.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 921.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  921.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_7 >  5.50
# |   |   |   |   |   |   |   |   |--- feature_19 <= 526.50
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 704.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [124000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  704.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= 151.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  151.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_19 >  526.50
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 1007.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 775.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  775.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [180000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  1007.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 783.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [159500.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  783.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |--- feature_11 >  969.50
# |   |   |   |   |--- feature_12 <= 1150.00
# |   |   |   |   |   |--- feature_18 <= 1.50
# |   |   |   |   |   |   |--- feature_19 <= 222.50
# |   |   |   |   |   |   |   |--- feature_9 <= 2006.50
# |   |   |   |   |   |   |   |   |--- feature_11 <= 1001.00
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 5.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 990.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [123600.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  990.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [118000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  5.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [108000.00]
# |   |   |   |   |   |   |   |   |--- feature_11 >  1001.00
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= 1073.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [80000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  1073.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [84500.00]
# |   |   |   |   |   |   |   |--- feature_9 >  2006.50
# |   |   |   |   |   |   |   |   |--- value: [147000.00]
# |   |   |   |   |   |   |--- feature_19 >  222.50
# |   |   |   |   |   |   |   |--- feature_8 <= 1916.00
# |   |   |   |   |   |   |   |   |--- value: [85000.00]
# |   |   |   |   |   |   |   |--- feature_8 >  1916.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= 1953.00
# |   |   |   |   |   |   |   |   |   |--- feature_17 <= 1935.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [113000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_17 >  1935.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1951.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  1951.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [123500.00]
# |   |   |   |   |   |   |   |   |--- feature_9 >  1953.00
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 2006.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  2006.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [109000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1019.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [149900.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  1019.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- feature_18 >  1.50
# |   |   |   |   |   |   |--- feature_8 <= 1951.50
# |   |   |   |   |   |   |   |--- feature_7 <= 5.50
# |   |   |   |   |   |   |   |   |--- feature_12 <= 1098.50
# |   |   |   |   |   |   |   |   |   |--- value: [128000.00]
# |   |   |   |   |   |   |   |   |--- feature_12 >  1098.50
# |   |   |   |   |   |   |   |   |   |--- value: [120000.00]
# |   |   |   |   |   |   |   |--- feature_7 >  5.50
# |   |   |   |   |   |   |   |   |--- value: [110500.00]
# |   |   |   |   |   |   |--- feature_8 >  1951.50
# |   |   |   |   |   |   |   |--- feature_10 <= 260.50
# |   |   |   |   |   |   |   |   |--- feature_17 <= 2003.50
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= 980.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_14 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_14 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [128000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  980.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1962.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  1962.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 11
# |   |   |   |   |   |   |   |   |--- feature_17 >  2003.50
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [176000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  4.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 1133.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  1133.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [142500.00]
# |   |   |   |   |   |   |   |--- feature_10 >  260.50
# |   |   |   |   |   |   |   |   |--- feature_17 <= 1971.00
# |   |   |   |   |   |   |   |   |   |--- feature_16 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [160000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_16 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [159950.00]
# |   |   |   |   |   |   |   |   |--- feature_17 >  1971.00
# |   |   |   |   |   |   |   |   |   |--- value: [169900.00]
# |   |   |   |   |--- feature_12 >  1150.00
# |   |   |   |   |   |--- feature_7 <= 5.50
# |   |   |   |   |   |   |--- feature_9 <= 1958.50
# |   |   |   |   |   |   |   |--- feature_17 <= 1957.50
# |   |   |   |   |   |   |   |   |--- feature_19 <= 269.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1952.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [125000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  1952.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [132000.00]
# |   |   |   |   |   |   |   |   |--- feature_19 >  269.00
# |   |   |   |   |   |   |   |   |   |--- feature_19 <= 334.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [145000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_19 >  334.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [157000.00]
# |   |   |   |   |   |   |   |--- feature_17 >  1957.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 1954.00
# |   |   |   |   |   |   |   |   |   |--- value: [100000.00]
# |   |   |   |   |   |   |   |   |--- feature_9 >  1954.00
# |   |   |   |   |   |   |   |   |   |--- value: [60000.00]
# |   |   |   |   |   |   |--- feature_9 >  1958.50
# |   |   |   |   |   |   |   |--- feature_16 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_17 <= 1961.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1192.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1956.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [126175.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  1956.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  1192.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1215.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [109900.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  1215.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [98600.00]
# |   |   |   |   |   |   |   |   |--- feature_17 >  1961.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1982.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_18 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_18 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  1982.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [179000.00]
# |   |   |   |   |   |   |   |--- feature_16 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 1965.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1962.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [155000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  1962.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [180500.00]
# |   |   |   |   |   |   |   |   |--- feature_9 >  1965.00
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_18 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_18 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 1220.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [154000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  1220.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |--- feature_7 >  5.50
# |   |   |   |   |   |   |--- feature_15 <= 4.50
# |   |   |   |   |   |   |   |--- feature_16 <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [208300.00]
# |   |   |   |   |   |   |   |--- feature_16 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [235000.00]
# |   |   |   |   |   |   |--- feature_15 >  4.50
# |   |   |   |   |   |   |   |--- feature_9 <= 1963.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 1956.50
# |   |   |   |   |   |   |   |   |   |--- feature_16 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [125000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_16 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [139000.00]
# |   |   |   |   |   |   |   |   |--- feature_9 >  1956.50
# |   |   |   |   |   |   |   |   |   |--- feature_19 <= 516.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1248.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  1248.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_19 >  516.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [143000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [142000.00]
# |   |   |   |   |   |   |   |--- feature_9 >  1963.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 2005.00
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 2001.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= 100.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  100.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  2001.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 1208.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  1208.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [145000.00]
# |   |   |   |   |   |   |   |   |--- feature_9 >  2005.00
# |   |   |   |   |   |   |   |   |   |--- feature_19 <= 450.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 1335.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [176432.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  1335.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [177000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_19 >  450.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 1312.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  1312.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [194700.00]
# |   |   |--- feature_13 >  1378.50
# |   |   |   |--- feature_7 <= 5.50
# |   |   |   |   |--- feature_16 <= 0.50
# |   |   |   |   |   |--- feature_13 <= 2486.50
# |   |   |   |   |   |   |--- feature_17 <= 1946.50
# |   |   |   |   |   |   |   |--- feature_9 <= 1978.50
# |   |   |   |   |   |   |   |   |--- feature_19 <= 210.00
# |   |   |   |   |   |   |   |   |   |--- value: [138887.00]
# |   |   |   |   |   |   |   |   |--- feature_19 >  210.00
# |   |   |   |   |   |   |   |   |   |--- feature_17 <= 1917.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 <= 9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [107400.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 >  9.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [106000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_17 >  1917.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [79000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 >  6.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |--- feature_9 >  1978.50
# |   |   |   |   |   |   |   |   |--- feature_17 <= 1920.50
# |   |   |   |   |   |   |   |   |   |--- feature_18 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [135000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_18 >  1.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [132000.00]
# |   |   |   |   |   |   |   |   |--- feature_17 >  1920.50
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= 1611.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [125000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  1611.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [124000.00]
# |   |   |   |   |   |   |--- feature_17 >  1946.50
# |   |   |   |   |   |   |   |--- feature_8 <= 1963.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 3.50
# |   |   |   |   |   |   |   |   |   |--- value: [85000.00]
# |   |   |   |   |   |   |   |   |--- feature_7 >  3.50
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 6.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 947.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  947.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  6.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 1461.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  1461.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |--- feature_8 >  1963.50
# |   |   |   |   |   |   |   |   |--- feature_15 <= 7.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1983.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1965.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [190000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  1965.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [185000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  1983.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_14 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [167000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_14 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [167500.00]
# |   |   |   |   |   |   |   |   |--- feature_15 >  7.50
# |   |   |   |   |   |   |   |   |   |--- feature_19 <= 458.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [150000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  4.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_19 >  458.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1704.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  1704.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- feature_13 >  2486.50
# |   |   |   |   |   |   |--- feature_13 <= 2617.50
# |   |   |   |   |   |   |   |--- value: [189000.00]
# |   |   |   |   |   |   |--- feature_13 >  2617.50
# |   |   |   |   |   |   |   |--- value: [200000.00]
# |   |   |   |   |--- feature_16 >  0.50
# |   |   |   |   |   |--- feature_11 <= 1302.50
# |   |   |   |   |   |   |--- feature_9 <= 2004.00
# |   |   |   |   |   |   |   |--- feature_12 <= 1047.00
# |   |   |   |   |   |   |   |   |--- feature_10 <= 238.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1945.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 1667.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  1667.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  1945.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 783.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [127000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  783.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [91500.00]
# |   |   |   |   |   |   |   |   |--- feature_10 >  238.00
# |   |   |   |   |   |   |   |   |   |--- feature_19 <= 252.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [175000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_19 >  252.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [169500.00]
# |   |   |   |   |   |   |   |--- feature_12 >  1047.00
# |   |   |   |   |   |   |   |   |--- feature_12 <= 1290.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1972.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1065.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  1065.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  1972.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [197500.00]
# |   |   |   |   |   |   |   |   |--- feature_12 >  1290.00
# |   |   |   |   |   |   |   |   |   |--- feature_17 <= 1995.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 <= 651.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 >  651.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_17 >  1995.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 1450.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [168000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  1450.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [175000.00]
# |   |   |   |   |   |   |--- feature_9 >  2004.00
# |   |   |   |   |   |   |   |--- feature_9 <= 2007.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 2006.50
# |   |   |   |   |   |   |   |   |   |--- value: [115000.00]
# |   |   |   |   |   |   |   |   |--- feature_9 >  2006.50
# |   |   |   |   |   |   |   |   |   |--- value: [104900.00]
# |   |   |   |   |   |   |   |--- feature_9 >  2007.50
# |   |   |   |   |   |   |   |   |--- value: [131000.00]
# |   |   |   |   |   |--- feature_11 >  1302.50
# |   |   |   |   |   |   |--- feature_5 <= 0.50
# |   |   |   |   |   |   |   |--- feature_9 <= 1996.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 1994.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1961.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 <= 487.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 >  487.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [149900.00]
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  1961.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 <= 803.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 >  803.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [186700.00]
# |   |   |   |   |   |   |   |   |--- feature_9 >  1994.50
# |   |   |   |   |   |   |   |   |   |--- value: [121500.00]
# |   |   |   |   |   |   |   |--- feature_9 >  1996.50
# |   |   |   |   |   |   |   |   |--- feature_18 <= 1.50
# |   |   |   |   |   |   |   |   |   |--- value: [207500.00]
# |   |   |   |   |   |   |   |   |--- feature_18 >  1.50
# |   |   |   |   |   |   |   |   |   |--- value: [218000.00]
# |   |   |   |   |   |   |--- feature_5 >  0.50
# |   |   |   |   |   |   |   |--- feature_13 <= 1826.50
# |   |   |   |   |   |   |   |   |--- feature_7 <= 4.50
# |   |   |   |   |   |   |   |   |   |--- value: [256000.00]
# |   |   |   |   |   |   |   |   |--- feature_7 >  4.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1411.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [223500.00]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  1411.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [228950.00]
# |   |   |   |   |   |   |   |--- feature_13 >  1826.50
# |   |   |   |   |   |   |   |   |--- value: [190000.00]
# |   |   |   |--- feature_7 >  5.50
# |   |   |   |   |--- feature_18 <= 1.50
# |   |   |   |   |   |--- feature_13 <= 2035.00
# |   |   |   |   |   |   |--- feature_11 <= 543.50
# |   |   |   |   |   |   |   |--- feature_9 <= 1976.50
# |   |   |   |   |   |   |   |   |--- value: [89500.00]
# |   |   |   |   |   |   |   |--- feature_9 >  1976.50
# |   |   |   |   |   |   |   |   |--- value: [117000.00]
# |   |   |   |   |   |   |--- feature_11 >  543.50
# |   |   |   |   |   |   |   |--- feature_9 <= 1954.00
# |   |   |   |   |   |   |   |   |--- feature_12 <= 781.50
# |   |   |   |   |   |   |   |   |   |--- value: [177500.00]
# |   |   |   |   |   |   |   |   |--- feature_12 >  781.50
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= 1470.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1943.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [132500.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  1943.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [97500.00]
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  1470.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1052.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 7
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  1052.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [115000.00]
# |   |   |   |   |   |   |   |--- feature_9 >  1954.00
# |   |   |   |   |   |   |   |   |--- feature_11 <= 728.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 702.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 <= 1950.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [165000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 >  1950.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [161750.00]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  702.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [188700.00]
# |   |   |   |   |   |   |   |   |--- feature_11 >  728.50
# |   |   |   |   |   |   |   |   |   |--- feature_19 <= 296.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1062.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  1062.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_19 >  296.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 993.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  993.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |--- feature_13 >  2035.00
# |   |   |   |   |   |   |--- feature_9 <= 1998.50
# |   |   |   |   |   |   |   |--- feature_17 <= 1942.00
# |   |   |   |   |   |   |   |   |--- value: [136000.00]
# |   |   |   |   |   |   |   |--- feature_17 >  1942.00
# |   |   |   |   |   |   |   |   |--- feature_11 <= 850.00
# |   |   |   |   |   |   |   |   |   |--- value: [169000.00]
# |   |   |   |   |   |   |   |   |--- feature_11 >  850.00
# |   |   |   |   |   |   |   |   |   |--- feature_19 <= 254.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [200000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_19 >  254.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [193500.00]
# |   |   |   |   |   |   |--- feature_9 >  1998.50
# |   |   |   |   |   |   |   |--- value: [259500.00]
# |   |   |   |   |--- feature_18 >  1.50
# |   |   |   |   |   |--- feature_13 <= 2059.00
# |   |   |   |   |   |   |--- feature_9 <= 1990.50
# |   |   |   |   |   |   |   |--- feature_11 <= 1561.00
# |   |   |   |   |   |   |   |   |--- feature_10 <= 451.50
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 1672.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 1650.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 16
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  1650.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [215000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  1672.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [127500.00]
# |   |   |   |   |   |   |   |   |--- feature_10 >  451.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1951.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [220000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  1951.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [185000.00]
# |   |   |   |   |   |   |   |--- feature_11 >  1561.00
# |   |   |   |   |   |   |   |   |--- feature_15 <= 7.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1972.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [223000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  1972.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1643.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [184000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  1643.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_15 >  7.50
# |   |   |   |   |   |   |   |   |   |--- value: [150900.00]
# |   |   |   |   |   |   |--- feature_9 >  1990.50
# |   |   |   |   |   |   |   |--- feature_13 <= 1715.50
# |   |   |   |   |   |   |   |   |--- feature_19 <= 477.50
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= 1690.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 <= 473.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 >  473.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [130500.00]
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  1690.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [130000.00]
# |   |   |   |   |   |   |   |   |--- feature_19 >  477.50
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 1453.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1998.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  1998.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  1453.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1995.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  1995.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |--- feature_13 >  1715.50
# |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |--- feature_17 <= 1960.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [230000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_17 >  1960.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 925.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  925.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 979.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 <= 470.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 >  470.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  979.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 2002.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  2002.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [257500.00]
# |   |   |   |   |   |--- feature_13 >  2059.00
# |   |   |   |   |   |   |--- feature_12 <= 1488.50
# |   |   |   |   |   |   |   |--- feature_19 <= 389.50
# |   |   |   |   |   |   |   |   |--- feature_12 <= 1375.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 1973.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [239000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  1973.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [240000.00]
# |   |   |   |   |   |   |   |   |--- feature_12 >  1375.50
# |   |   |   |   |   |   |   |   |   |--- value: [277000.00]
# |   |   |   |   |   |   |   |--- feature_19 >  389.50
# |   |   |   |   |   |   |   |   |--- feature_12 <= 1455.00
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1913.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [133900.00]
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  1913.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 <= 1950.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_17 >  1950.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_12 >  1455.00
# |   |   |   |   |   |   |   |   |   |--- value: [129000.00]
# |   |   |   |   |   |   |--- feature_12 >  1488.50
# |   |   |   |   |   |   |   |--- feature_11 <= 1532.00
# |   |   |   |   |   |   |   |   |--- feature_19 <= 476.00
# |   |   |   |   |   |   |   |   |   |--- value: [274970.00]
# |   |   |   |   |   |   |   |   |--- feature_19 >  476.00
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= 2723.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1129.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [250000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  1129.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  2723.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [272000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [256000.00]
# |   |   |   |   |   |   |   |--- feature_11 >  1532.00
# |   |   |   |   |   |   |   |   |--- feature_17 <= 1965.50
# |   |   |   |   |   |   |   |   |   |--- value: [217000.00]
# |   |   |   |   |   |   |   |   |--- feature_17 >  1965.50
# |   |   |   |   |   |   |   |   |   |--- value: [210000.00]
# |   |--- feature_7 >  6.50
# |   |   |--- feature_13 <= 2020.00
# |   |   |   |--- feature_11 <= 1469.00
# |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |--- feature_11 <= 700.00
# |   |   |   |   |   |   |--- feature_19 <= 342.00
# |   |   |   |   |   |   |   |--- feature_12 <= 702.00
# |   |   |   |   |   |   |   |   |--- value: [116900.00]
# |   |   |   |   |   |   |   |--- feature_12 >  702.00
# |   |   |   |   |   |   |   |   |--- feature_13 <= 1295.00
# |   |   |   |   |   |   |   |   |   |--- value: [139400.00]
# |   |   |   |   |   |   |   |   |--- feature_13 >  1295.00
# |   |   |   |   |   |   |   |   |   |--- value: [143000.00]
# |   |   |   |   |   |   |--- feature_19 >  342.00
# |   |   |   |   |   |   |   |--- feature_12 <= 507.50
# |   |   |   |   |   |   |   |   |--- value: [198500.00]
# ...
# |   |   |   |   |   |   |   |   |   |   |--- value: [324000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_17 >  2000.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [372402.00]
# |   |   |   |   |   |   |   |   |--- feature_15 >  6.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1825.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1723.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  1723.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  1825.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 1840.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [280000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  1840.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [257000.00]
# |   |   |   |   |--- feature_0 >  0.50
# |   |   |   |   |   |--- feature_8 <= 2007.50
# |   |   |   |   |   |   |--- feature_9 <= 2005.50
# |   |   |   |   |   |   |   |--- value: [274000.00]
# |   |   |   |   |   |   |--- feature_9 >  2005.50
# |   |   |   |   |   |   |   |--- value: [318000.00]
# |   |   |   |   |   |--- feature_8 >  2007.50
# |   |   |   |   |   |   |--- feature_10 <= 306.00
# |   |   |   |   |   |   |   |--- value: [392500.00]
# |   |   |   |   |   |   |--- feature_10 >  306.00
# |   |   |   |   |   |   |   |--- value: [394617.00]
# |   |   |--- feature_13 >  1973.00
# |   |   |   |--- feature_12 <= 1459.50
# |   |   |   |   |--- feature_8 <= 1895.00
# |   |   |   |   |   |--- value: [122000.00]
# |   |   |   |   |--- feature_8 >  1895.00
# |   |   |   |   |   |--- feature_18 <= 2.50
# |   |   |   |   |   |   |--- feature_15 <= 10.50
# |   |   |   |   |   |   |   |--- feature_12 <= 1406.50
# |   |   |   |   |   |   |   |   |--- feature_19 <= 850.00
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 8.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [228500.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  8.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1040.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [267000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  1040.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_19 >  850.00
# |   |   |   |   |   |   |   |   |   |--- value: [287000.00]
# |   |   |   |   |   |   |   |--- feature_12 >  1406.50
# |   |   |   |   |   |   |   |   |--- value: [302000.00]
# |   |   |   |   |   |   |--- feature_15 >  10.50
# |   |   |   |   |   |   |   |--- feature_2 <= 0.50
# |   |   |   |   |   |   |   |   |--- value: [299800.00]
# |   |   |   |   |   |   |   |--- feature_2 >  0.50
# |   |   |   |   |   |   |   |   |--- value: [303477.00]
# |   |   |   |   |   |--- feature_18 >  2.50
# |   |   |   |   |   |   |--- feature_10 <= 365.00
# |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_9 <= 2002.00
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 1071.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [248000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  1071.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [250000.00]
# |   |   |   |   |   |   |   |   |--- feature_9 >  2002.00
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 1148.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 1085.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [275500.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  1085.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [281213.00]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  1148.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1166.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [290000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  1166.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [285000.00]
# |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_17 <= 2006.00
# |   |   |   |   |   |   |   |   |   |--- value: [309000.00]
# |   |   |   |   |   |   |   |   |--- feature_17 >  2006.00
# |   |   |   |   |   |   |   |   |   |--- value: [339750.00]
# |   |   |   |   |   |   |--- feature_10 >  365.00
# |   |   |   |   |   |   |   |--- feature_17 <= 1996.50
# |   |   |   |   |   |   |   |   |--- value: [290000.00]
# |   |   |   |   |   |   |   |--- feature_17 >  1996.50
# |   |   |   |   |   |   |   |   |--- feature_15 <= 9.50
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= 526.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [325300.00]
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  526.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 <= 7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [340000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_15 >  7.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_15 >  9.50
# |   |   |   |   |   |   |   |   |   |--- feature_17 <= 2005.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [354000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_17 >  2005.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [361919.00]
# |   |   |   |--- feature_12 >  1459.50
# |   |   |   |   |--- feature_15 <= 11.50
# |   |   |   |   |   |--- feature_19 <= 898.00
# |   |   |   |   |   |   |--- feature_13 <= 3211.00
# |   |   |   |   |   |   |   |--- feature_9 <= 1994.50
# |   |   |   |   |   |   |   |   |--- feature_11 <= 2101.50
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1963.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [315000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  1963.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [301500.00]
# |   |   |   |   |   |   |   |   |--- feature_11 >  2101.50
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 2370.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [268000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  2370.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [278000.00]
# |   |   |   |   |   |   |   |--- feature_9 >  1994.50
# |   |   |   |   |   |   |   |   |--- feature_10 <= 382.00
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= 2313.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1791.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  1791.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [305900.00]
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  2313.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 1953.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [359100.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  1953.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_10 >  382.00
# |   |   |   |   |   |   |   |   |   |--- feature_17 <= 1994.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [402000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_17 >  1994.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 2079.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [372500.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  2079.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [350000.00]
# |   |   |   |   |   |   |--- feature_13 >  3211.00
# |   |   |   |   |   |   |   |--- feature_17 <= 1994.00
# |   |   |   |   |   |   |   |   |--- value: [430000.00]
# |   |   |   |   |   |   |   |--- feature_17 >  1994.00
# |   |   |   |   |   |   |   |   |--- value: [410000.00]
# |   |   |   |   |   |--- feature_19 >  898.00
# |   |   |   |   |   |   |--- feature_1 <= 0.50
# |   |   |   |   |   |   |   |--- value: [381000.00]
# |   |   |   |   |   |   |--- feature_1 >  0.50
# |   |   |   |   |   |   |   |--- feature_19 <= 980.00
# |   |   |   |   |   |   |   |   |--- value: [440000.00]
# |   |   |   |   |   |   |   |--- feature_19 >  980.00
# |   |   |   |   |   |   |   |   |--- feature_10 <= 170.00
# |   |   |   |   |   |   |   |   |   |--- value: [423000.00]
# |   |   |   |   |   |   |   |   |--- feature_10 >  170.00
# |   |   |   |   |   |   |   |   |   |--- value: [424870.00]
# |   |   |   |   |--- feature_15 >  11.50
# |   |   |   |   |   |--- value: [538000.00]
# |   |--- feature_7 >  8.50
# |   |   |--- feature_9 <= 1997.50
# |   |   |   |--- feature_17 <= 1994.00
# |   |   |   |   |--- feature_19 <= 867.00
# |   |   |   |   |   |--- value: [475000.00]
# |   |   |   |   |--- feature_19 >  867.00
# |   |   |   |   |   |--- value: [385000.00]
# |   |   |   |--- feature_17 >  1994.00
# |   |   |   |   |--- feature_11 <= 2163.00
# |   |   |   |   |   |--- value: [625000.00]
# |   |   |   |   |--- feature_11 >  2163.00
# |   |   |   |   |   |--- value: [745000.00]
# |   |   |--- feature_9 >  1997.50
# |   |   |   |--- feature_13 <= 3908.00
# |   |   |   |   |--- feature_13 <= 2229.00
# |   |   |   |   |   |--- feature_12 <= 1853.00
# |   |   |   |   |   |   |--- feature_10 <= 30.00
# |   |   |   |   |   |   |   |--- value: [239000.00]
# |   |   |   |   |   |   |--- feature_10 >  30.00
# |   |   |   |   |   |   |   |--- feature_13 <= 1691.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= 2006.00
# |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1655.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [285000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  0.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [277500.00]
# |   |   |   |   |   |   |   |   |   |--- feature_11 >  1655.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [266000.00]
# |   |   |   |   |   |   |   |   |--- feature_9 >  2006.00
# |   |   |   |   |   |   |   |   |   |--- value: [325000.00]
# |   |   |   |   |   |   |   |--- feature_13 >  1691.00
# |   |   |   |   |   |   |   |   |--- feature_15 <= 7.50
# |   |   |   |   |   |   |   |   |   |--- feature_18 <= 2.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 2002.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [328900.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  2002.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [319900.00]
# |   |   |   |   |   |   |   |   |   |--- feature_18 >  2.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 <= 1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 >  1.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [377500.00]
# |   |   |   |   |   |   |   |   |--- feature_15 >  7.50
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= 2168.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 1844.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  1844.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [326000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  2168.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 <= 787.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [350000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 >  787.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [335000.00]
# |   |   |   |   |   |--- feature_12 >  1853.00
# |   |   |   |   |   |   |--- feature_17 <= 2006.50
# |   |   |   |   |   |   |   |--- feature_19 <= 723.00
# |   |   |   |   |   |   |   |   |--- value: [377426.00]
# |   |   |   |   |   |   |   |--- feature_19 >  723.00
# |   |   |   |   |   |   |   |   |--- feature_11 <= 1942.50
# |   |   |   |   |   |   |   |   |   |--- value: [320000.00]
# |   |   |   |   |   |   |   |   |--- feature_11 >  1942.50
# |   |   |   |   |   |   |   |   |   |--- value: [315000.00]
# |   |   |   |   |   |   |--- feature_17 >  2006.50
# |   |   |   |   |   |   |   |--- feature_8 <= 2006.50
# |   |   |   |   |   |   |   |   |--- value: [415298.00]
# |   |   |   |   |   |   |   |--- feature_8 >  2006.50
# |   |   |   |   |   |   |   |   |--- feature_8 <= 2008.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 2008.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [385000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  2008.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [378500.00]
# |   |   |   |   |   |   |   |   |--- feature_8 >  2008.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [402861.00]
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [395192.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  2009.50
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [394432.00]
# |   |   |   |   |--- feature_13 >  2229.00
# |   |   |   |   |   |--- feature_8 <= 2007.50
# |   |   |   |   |   |   |--- feature_12 <= 1546.50
# |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |--- feature_11 <= 1315.00
# |   |   |   |   |   |   |   |   |   |--- value: [325000.00]
# |   |   |   |   |   |   |   |   |--- feature_11 >  1315.00
# |   |   |   |   |   |   |   |   |   |--- value: [333168.00]
# |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |--- feature_13 <= 2460.00
# |   |   |   |   |   |   |   |   |   |--- value: [345000.00]
# |   |   |   |   |   |   |   |   |--- feature_13 >  2460.00
# |   |   |   |   |   |   |   |   |   |--- value: [342643.00]
# |   |   |   |   |   |   |--- feature_12 >  1546.50
# |   |   |   |   |   |   |   |--- feature_9 <= 2002.50
# |   |   |   |   |   |   |   |   |--- value: [466500.00]
# |   |   |   |   |   |   |   |--- feature_9 >  2002.50
# |   |   |   |   |   |   |   |   |--- feature_11 <= 2000.50
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 2005.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [412500.00]
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  2005.00
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 1765.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [426000.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  1765.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [437154.00]
# |   |   |   |   |   |   |   |   |--- feature_11 >  2000.50
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [380000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- value: [386250.00]
# |   |   |   |   |   |--- feature_8 >  2007.50
# |   |   |   |   |   |   |--- feature_15 <= 11.50
# |   |   |   |   |   |   |   |--- feature_10 <= 234.00
# |   |   |   |   |   |   |   |   |--- value: [555000.00]
# |   |   |   |   |   |   |   |--- feature_10 >  234.00
# |   |   |   |   |   |   |   |   |--- feature_9 <= 2008.50
# |   |   |   |   |   |   |   |   |   |--- value: [446261.00]
# |   |   |   |   |   |   |   |   |--- feature_9 >  2008.50
# |   |   |   |   |   |   |   |   |   |--- feature_19 <= 993.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [485000.00]
# |   |   |   |   |   |   |   |   |   |--- feature_19 >  993.00
# |   |   |   |   |   |   |   |   |   |   |--- value: [501837.00]
# |   |   |   |   |   |   |--- feature_15 >  11.50
# |   |   |   |   |   |   |   |--- value: [582933.00]
# |   |   |   |--- feature_13 >  3908.00
# |   |   |   |   |--- feature_13 <= 5159.00
# |   |   |   |   |   |--- value: [184750.00]
# |   |   |   |   |--- feature_13 >  5159.00
# |   |   |   |   |   |--- value: [160000.00]

# %% [markdown]
# ## Random forest regressor
#
# Scaling is not necessary for random forests.
#
# ### Determine the optimal number of estimators

# %%
model = RandomForestRegressor()
estimators = np.arange(1, 101, 1)
repitions = np.arange(0, 50)
df = pd.DataFrame(columns =['n_estimators', 'rmse'])

# Create a random forest regressor with every possible number of estimators between 1 and 100
for n in estimators:
    
    # For every number of estimators, repeat modelling 50 times
    for i in repitions:
        
        # Fit regression model
        model.set_params(n_estimators=n)
        model.fit(X_train, y_train)

        # Predict
        y_pred = model.predict(X_test)

        # Compute root mean squared error 
        rmse = np.sqrt(mean_squared_error(y_pred, y_test))
        
        # Add row to dataframe
        df = df.append({'n_estimators': n, 'rmse': rmse}, ignore_index=True)
    
# Plot the avg, max, and min rmse of the random forests for every number of estimators
data = df.groupby('n_estimators')['rmse'].agg(['min', 'max', 'mean']).reset_index()
print(data)

ax  = data.plot(x='n_estimators', y='mean', c='white', figsize=(20, 10))
plt.title("Avg-max-min plot of the RMSE of random forests depending on n_estimators")
plt.xlabel('n_estimators')
plt.ylabel('RMSE')
plt.fill_between(x='n_estimators',y1='min',y2='max', data=data)
# Out:
#     n_estimators           min           max          mean
# 0            1.0  35814.260106  58077.154660  43418.123484
# 1            2.0  31751.601616  48904.906363  38021.098639
# 2            3.0  30660.790341  43429.747136  34876.817865
# 3            4.0  29135.914659  39234.811144  33510.620848
# 4            5.0  29392.250854  38478.327020  33044.905208
# ..           ...           ...           ...           ...
# 95          96.0  28695.015790  31001.761400  29651.975046
# 96          97.0  28506.081533  30905.785093  29811.388671
# 97          98.0  28415.230575  30708.461816  29671.490520
# 98          99.0  28987.736154  30947.737274  29721.873304
# 99         100.0  28952.595009  31369.833648  29810.215184
#
# [100 rows x 4 columns]

# %% [markdown]
# ### Optimal random forest

# %%
regressor = RandomForestRegressor(n_estimators=40, random_state=0)
regressor.fit(X_train.values, y_train)

y_pred = regressor.predict(X_test)

# compute root mean squared error 
rmse = np.sqrt(mean_squared_error(y_pred, y_test))
print("RMSE:", rmse)
# Out:
# RMSE: 29802.836590304003
# /Users/veerleblom/opt/anaconda3/envs/progLab/lib/python3.7/site-packages/sklearn/base.py:439: UserWarning: X has feature names, but RandomForestRegressor was fitted without feature names
#   f"X has feature names, but {self.__class__.__name__} was fitted without"

# %% [markdown]
# ## Extra trees
#
# ### Determine the optimal number of estimators

# %%
model = ExtraTreesRegressor()
estimators = np.arange(1, 101, 1)
repitions = np.arange(0, 50)
df = pd.DataFrame(columns =['n_estimators', 'rmse'])

# Create a random forest regressor with every possible number of estimators between 1 and 100
for n in estimators:
    
    # For every number of estimators, repeat modelling 50 times
    for i in repitions:
        
        # Fit regression model
        model.set_params(n_estimators=n)
        model.fit(X_train, y_train)

        # Predict
        y_pred = model.predict(X_test)

        # Compute root mean squared error 
        rmse = np.sqrt(mean_squared_error(y_pred, y_test))
        
        # Add row to dataframe
        df = df.append({'n_estimators': n, 'rmse': rmse}, ignore_index=True)
    
# Plot the avg, max, and min rmse of the random forests for every number of estimators
data = df.groupby('n_estimators')['rmse'].agg(['min', 'max', 'mean']).reset_index()
print(data)

ax  = data.plot(x='n_estimators', y='mean', c='white', figsize=(20, 10))
plt.title("Avg-max-min plot of the RMSE of extra trees depending on n_estimators")
plt.xlabel('n_estimators')
plt.ylabel('RMSE')
plt.fill_between(x='n_estimators',y1='min',y2='max', data=data)
# Out:
#     n_estimators           min           max          mean
# 0            1.0  35835.177507  64221.247079  42965.948836
# 1            2.0  31253.472632  44784.311433  35875.751872
# 2            3.0  30659.799072  38976.784594  34394.052223
# 3            4.0  29001.628776  40455.876917  32695.887828
# 4            5.0  28179.394384  36557.677049  32103.849683
# ..           ...           ...           ...           ...
# 95          96.0  27776.006542  29726.551324  29059.985389
# 96          97.0  27962.225672  29974.644766  29108.963891
# 97          98.0  28397.561616  29816.037211  29089.115509
# 98          99.0  28445.507132  29880.835833  29060.195440
# 99         100.0  28157.988206  29742.442285  29029.918448
#
# [100 rows x 4 columns]

# %% [markdown]
# ## Optimal extra trees

# %%
clf = ExtraTreesRegressor(n_estimators=60) 

# Fit model
clf.fit(X_train, y_train)

# Predict
y_pred = clf.predict(X_test)

# Compute the root mean squared error 
rmse = np.sqrt(mean_squared_error(y_pred, y_test))
print("RMSE:", rmse )
# Out:
# RMSE: 29030.18349369697
